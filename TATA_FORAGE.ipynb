# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/dataset1.xlsx")
df[['first_name','last_name','gender','past_3_years_bike_related_purchases','DOB','job_title','job_industry','wealth_segment','deceased_input','owns_car','tenure']]
df.head()
# Out:
#   first_name last_name  gender past_3_years_bike_related_purchases  \
# 0     Darrel     Canet    Male                                  67
# 1     Katlin   Creddon  Female                                  56
# 2    Merrili   Brittin  Female                                  93
# 3      Abbey    Murrow    Male                                  27
# 4       Donn   Bonnell    Male                                  38
#
#                    DOB                 job_title   job_industry  \
# 0  1931-10-23 00:00:00        Recruiting Manager         Retail
# 1  1935-08-22 00:00:00        VP Quality Control         Retail
# 2  1940-09-22 00:00:00                       NaN       Property
# 3  1943-08-11 00:00:00  Environmental Specialist  Manufacturing
# 4  1944-01-24 00:00:00            Tax Accountant  Manufacturing
#
#       wealth_segment deceased_input             default owns_car tenure
# 0  Affluent Customer              N  1;DROP TABLE users       No      6
# ...

# %%
df.head()
# Out:
#   first_name last_name  gender past_3_years_bike_related_purchases  \
# 0     Darrel     Canet    Male                                  67
# 1     Katlin   Creddon  Female                                  56
# 2    Merrili   Brittin  Female                                  93
# 3      Abbey    Murrow    Male                                  27
# 4       Donn   Bonnell    Male                                  38
#
#                    DOB                 job_title   job_industry  \
# 0  1931-10-23 00:00:00        Recruiting Manager         Retail
# 1  1935-08-22 00:00:00        VP Quality Control         Retail
# 2  1940-09-22 00:00:00                       NaN       Property
# 3  1943-08-11 00:00:00  Environmental Specialist  Manufacturing
# 4  1944-01-24 00:00:00            Tax Accountant  Manufacturing
#
#       wealth_segment deceased_input             default owns_car tenure
# 0  Affluent Customer              N  1;DROP TABLE users       No      6
# ...

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry', 'wealth_segment', 'deceased_input', 'default',
#        'owns_car', 'tenure'],
#       dtype='object')

# %%
df
# Out:
#      first_name  last_name  gender past_3_years_bike_related_purchases  \
# 0        Darrel      Canet    Male                                  67
# 1        Katlin    Creddon  Female                                  56
# 2       Merrili    Brittin  Female                                  93
# 3         Abbey     Murrow    Male                                  27
# 4          Donn    Bonnell    Male                                  38
# ...         ...        ...     ...                                 ...
# 3996      Ulick     Daspar       U                                  68
# 3997      Nissa     Conrad       U                                  35
# 3998      Kylie      Epine       U                                  19
# 3999     Teodor  Alfonsini       U                                  72
# 4000     Sarene    Woolley       U                                  60
#
#                       DOB                 job_title   job_industry  \
# ...

# %% [markdown]
# ```
# # This is formatted as code
# 1-male
# 0=female
# 2-non-binary
#
# ```

# %%
df['gender'].mask(df['gender'] == 'Female', 0, inplace=True)

# %%
df['gender'].mask(df['gender'] == 'Femal', 0, inplace=True)

# %%
df['gender'].mask(df['gender'] == 'F', 0, inplace=True)

# %%
df['gender'].unique()
# Out:
# array([1, 0, 2], dtype=object)

# %%
df['gender'].mask(df['gender'] == 'Male', 1, inplace=True)

# %%
df['gender'].mask(df['gender'] == 'M', 1, inplace=True)

# %%
df['gender'].mask(df['gender'] == 'gender',2, inplace=True)

# %%
df['gender'].mask(df['gender'] == 'U', 2, inplace=True)

# %%
df.head()
# Out:
#   first_name last_name gender past_3_years_bike_related_purchases  \
# 0     Darrel     Canet      1                                  67
# 1     Katlin   Creddon      0                                  56
# 2    Merrili   Brittin      0                                  93
# 3      Abbey    Murrow      1                                  27
# 4       Donn   Bonnell      1                                  38
#
#                    DOB                 job_title   job_industry  \
# 0  1931-10-23 00:00:00        Recruiting Manager         Retail
# 1  1935-08-22 00:00:00        VP Quality Control         Retail
# 2  1940-09-22 00:00:00                       NaN       Property
# 3  1943-08-11 00:00:00  Environmental Specialist  Manufacturing
# 4  1944-01-24 00:00:00            Tax Accountant  Manufacturing
#
#       wealth_segment deceased_input             default  owns_car tenure
# 0  Affluent Customer              N  1;DROP TABLE users       0.0      6
# ...

# %%
df['owns_car'].mask(df['owns_car']=='No',0,inplace=True)

# %%
df['owns_car'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
df['owns_car'].mask(df['owns_car']=='Yes',1,inplace=True)

# %%
df['owns_car'].mask(df['owns_car']=='owns_car',1,inplace=True)

# %%
df['tenure'].unique()
# Out:
# array([6, 5, 16, 17, 8, 11, 15, 12, 20, 7, 10, 18, 14, 19, 9, 13, 4, 3,
#        22, 21, 2, 1, 0, nan], dtype=object)

# %%
df['tenure'].mask(df['tenure']=='tenure',0,inplace=True)

# %%
df['tenure'].mask(df['tenure']=='nan',0,inplace=True)

# %%
sns.barplot(df,x=df['tenure'],y=df['owns_car'])
plt.show()

# %% [markdown]
# 0- Females
# 1-Males
# 2-Non-binary

# %%
df['gender'].value_counts()
# Out:
# 0    2039
# 1    1873
# 2      89
# Name: gender, dtype: int64

# %%
df.isnull().sum()
# Out:
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry                           656
# wealth_segment                           0
# deceased_input                           0
# default                                339
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %% [markdown]
# **HEATMAP**

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# %%
data=df.isnull().sum()

# %%
df["owns_car"] = [float(str(i).replace(",", "")) for i in df["owns_car"]]
sns.heatmap(df["owns_car"], cmap ='RdYlGn', linewidths = 0.30, annot = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-3c92e425963a> in <cell line: 2>()
#       1 df["owns_car"] = [float(str(i).replace(",", "")) for i in df["owns_car"]]
# ----> 2 sns.heatmap(df["owns_car"], cmap ='RdYlGn', linewidths = 0.30, annot = True)
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# ...

# %%
df.describe()
# Out:
#           owns_car
# count  4001.000000
# mean      0.506123
# std       0.500025
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['owns_car'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %%
sns.lineplot(df, x=df['tenure'],y=df['owns_car'])
plt.show()

# %%
sns.barplot(df,x=df['gender'],y=df['owns_car'])
plt.show()
